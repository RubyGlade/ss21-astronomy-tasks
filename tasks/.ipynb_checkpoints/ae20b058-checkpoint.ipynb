# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# %%
hdul= fits.open('/Users/ganga/gll_iem_v02_P2_V11_DIFFUSE.fit')
#hdul.info()
#No: of HDU's is 2

# %%
hdr = hdul[0].header
#print(repr(hdr))
#What is the length of axis 3? - 30
#What is the axis 3 supposed to be? - Photon energy
#What are the units of axis 3? - MeV
#What is the name of the telescope? - GLAST
#What is the name of the observer? - MICHELSON

# %%
data = hdul[0].data
data.shape
img = data[0]
img.shape
plt.imshow(img, cmap='gray');
plt.colorbar()
